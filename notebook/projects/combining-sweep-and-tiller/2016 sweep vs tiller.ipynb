# %% [markdown]
# ## Purpose

# %% [markdown]
# Cleaning data, comparing numbers in two time series.
#
# Main problem to solve:
#
# - What is the relationship between observations recorded as "head counts" versus "sweeps"?

# %% [markdown]
# ## Import Data

# %%
import pandas

data_file = pandas.ExcelFile('2016 sweep vs tiller.xlsx')
sheets = dict(((sheet_name, data_file.parse(sheet_name))
          for sheet_name in data_file.sheet_names))

# %% [markdown]
# ## Explore Worksheets

# %% [markdown]
# !["Perfectly straight line in graph comparing supposedly independent variables in Head Count and Sweeps workbook, in Excel Online"](head-count-sweeps-graph-excel-online.png)

# %% [markdown]
# When I opened the workbook in Excel Online, I saw many sheets with rather unhelpful names, and what looked like a lot of data that had been copied from other worksheets.
#
# - There are two sources of actual observational data:
#   * "cereal sweeps" or just "sweeps"
#   * "head counts" or "tillers"
# - There's a graph in a worksheet called "head counts vs sweeps graphs" which demonstrates the analytical problem found by someone else.
# - Multiple editors have made changes or additions to the workbook, and nobody left notes.
# - It's not clear which data is "original" and which is duplicated.
# - The data supposedly being compared in the graph is cannot be the data that was intended for comparison.
#
# Because I can't trust that the data used in the graph was prepared accurately, I need to look at all the sheets and determine the most complete and unadulterated data sets. I'll determine which data belongs to each category, and compare the sets.

# %% [markdown]
# ### Compare Columns

# %% [markdown]
# I'll begin by listing the columns of all sheets, which will offer some descriptive terms for the data in each:

# %%
pandas.DataFrame(index=sheets.keys(), data=[frame.columns for frame in sheets.values()])
# Out:
#                                                0               1    \
# Head Counts                                   Site            Crop
# Sheet2                                          ID        Province
# Sweep Samples Cereals                           ID        Province
# Head Counts Edited                            Date            Site
# Sweep Samples Cereals Edited                  Date            Site
# Data Sheets Combined                            ID            Date
# Pivot chart LH phen                           None            None
# leafhoppers 2016 cereal sweeps     Collection_Date  Sample_by_week
# Sheet3                                        None            None
# aphid sweep vs head count                       ID            Date
# head counts vs sweeps graphs    Total_aphids_sweep     Aphids/head
#
#                                             2               3             4    \
# Head Counts                                Date           Field  Zadoks_stage
# Sheet2                          Collection_Date  Sample_by_week  Date_by_week
# Sweep Samples Cereals           Collection_Date  Sample_by_week  Date_by_week
# Head Counts Edited                         Crop           Field   Sample Type
# Sweep Samples Cereals Edited               Crop      Field_name   Sample Type
# Data Sheets Combined                       Site            Crop    Field_name
# Pivot chart LH phen                        None            None          None
# leafhoppers 2016 cereal sweeps     Date_by_week            Date   Julian_date
# Sheet3                                     None            None          None
# aphid sweep vs head count                  Site            Crop    Field_name
# head counts vs sweeps graphs         Unnamed: 2      Unnamed: 3    Unnamed: 4
#
#                                          5             6             7    \
# Head Counts                           Tiller      EGA_head      EGA_leaf
# Sheet2                                  Date   Julian_date          Site
# Sweep Samples Cereals                   Date   Julian_date          Site
# Head Counts Edited                Unnamed: 5  Zadoks_stage        Tiller
# Sweep Samples Cereals Edited    Total Sweeps    Unnamed: 6    Unnamed: 7
# Data Sheets Combined             Sample Type  Total Sweeps  Zadoks_stage
# Pivot chart LH phen                     None          None          None
# leafhoppers 2016 cereal sweeps          Site    Field_name          Crop
# Sheet3                                  None          None          None
# aphid sweep vs head count        Sample Type  Total Sweeps  Zadoks_stage
# head counts vs sweeps graphs      Unnamed: 5    Unnamed: 6    Unnamed: 7
#
#                                         8                  9    \
# Head Counts                        BCO_head           BCO_leaf
# Sheet2                           Field_name               Crop
# Sweep Samples Cereals            Field_name               Crop
# Head Counts Edited                EGA_alate            EGA_apt
# Sweep Samples Cereals Edited      EGA_alate            EGA_apt
# Data Sheets Combined                 Tiller          EGA_alate
# Pivot chart LH phen                    None               None
# leafhoppers 2016 cereal sweeps  Distance(m)  Number of Samples
# Sheet3                                 None               None
# aphid sweep vs head count            Tiller          EGA_alate
# head counts vs sweeps graphs     Unnamed: 8         Unnamed: 9
#
#                                            ...               \
# Head Counts                                ...
# Sheet2                                     ...
# Sweep Samples Cereals                      ...
# Head Counts Edited                         ...
# Sweep Samples Cereals Edited               ...
# Data Sheets Combined                       ...
# Pivot chart LH phen                        ...
# leafhoppers 2016 cereal sweeps             ...
# Sheet3                                     ...
# aphid sweep vs head count                  ...
# head counts vs sweeps graphs               ...
#
#                                                        134  \
# Head Counts                                           None
# Sheet2                               Hymenoptera_Figitidae
# Sweep Samples Cereals           Hymenoptera_Proctotrupidae
# Head Counts Edited                                    None
# Sweep Samples Cereals Edited                          None
# Data Sheets Combined                                  None
# Pivot chart LH phen                                   None
# leafhoppers 2016 cereal sweeps                        None
# Sheet3                                                None
# aphid sweep vs head count                             None
# head counts vs sweeps graphs                          None
#
#                                                      135  \
# Head Counts                                         None
# Sheet2                           Hymenoptera_Aphelinidae
# Sweep Samples Cereals           Hymenoptera_Pteromalidae
# Head Counts Edited                                  None
# Sweep Samples Cereals Edited                        None
# Data Sheets Combined                                None
# Pivot chart LH phen                                 None
# leafhoppers 2016 cereal sweeps                      None
# Sheet3                                              None
# aphid sweep vs head count                           None
# head counts vs sweeps graphs                        None
#
#                                                      136  \
# Head Counts                                         None
# Sheet2                          Hymenoptera_Perilampidae
# Sweep Samples Cereals                 Hymenoptera_Apidae
# Head Counts Edited                                  None
# Sweep Samples Cereals Edited                        None
# Data Sheets Combined                                None
# Pivot chart LH phen                                 None
# leafhoppers 2016 cereal sweeps                      None
# Sheet3                                              None
# aphid sweep vs head count                           None
# head counts vs sweeps graphs                        None
#
#                                                       137  \
# Head Counts                                          None
# Sheet2                           Hymenoptera_Chalcidoidea
# Sweep Samples Cereals           Hymenoptera_Diplazontinae
# Head Counts Edited                                   None
# Sweep Samples Cereals Edited                         None
# Data Sheets Combined                                 None
# Pivot chart LH phen                                  None
# leafhoppers 2016 cereal sweeps                       None
# Sheet3                                               None
# aphid sweep vs head count                            None
# head counts vs sweeps graphs                         None
#
#                                                         138  \
# Head Counts                                            None
# Sheet2                          Hymenoptera_Ichneumondoidea
# Sweep Samples Cereals                 Hymenoptera_Figitidae
# Head Counts Edited                                     None
# Sweep Samples Cereals Edited                           None
# Data Sheets Combined                                   None
# Pivot chart LH phen                                    None
# leafhoppers 2016 cereal sweeps                         None
# Sheet3                                                 None
# aphid sweep vs head count                              None
# head counts vs sweeps graphs                           None
#
#                                                         139  \
# Head Counts                                            None
# Sheet2                          Hymenoptera_Proctotrupoidea
# Sweep Samples Cereals               Hymenoptera_Aphelinidae
# Head Counts Edited                                     None
# Sweep Samples Cereals Edited                           None
# Data Sheets Combined                                   None
# Pivot chart LH phen                                    None
# leafhoppers 2016 cereal sweeps                         None
# Sheet3                                                 None
# aphid sweep vs head count                              None
# head counts vs sweeps graphs                           None
#
#                                                      140  \
# Head Counts                                         None
# Sheet2                                              None
# Sweep Samples Cereals           Hymenoptera_Perilampidae
# Head Counts Edited                                  None
# Sweep Samples Cereals Edited                        None
# Data Sheets Combined                                None
# Pivot chart LH phen                                 None
# leafhoppers 2016 cereal sweeps                      None
# Sheet3                                              None
# aphid sweep vs head count                           None
# head counts vs sweeps graphs                        None
#
#                                                      141  \
# Head Counts                                         None
# Sheet2                                              None
# Sweep Samples Cereals           Hymenoptera_Chalcidoidea
# Head Counts Edited                                  None
# Sweep Samples Cereals Edited                        None
# Data Sheets Combined                                None
# Pivot chart LH phen                                 None
# leafhoppers 2016 cereal sweeps                      None
# Sheet3                                              None
# aphid sweep vs head count                           None
# head counts vs sweeps graphs                        None
#
#                                                         142  \
# Head Counts                                            None
# Sheet2                                                 None
# Sweep Samples Cereals           Hymenoptera_Ichneumondoidea
# Head Counts Edited                                     None
# Sweep Samples Cereals Edited                           None
# Data Sheets Combined                                   None
# Pivot chart LH phen                                    None
# leafhoppers 2016 cereal sweeps                         None
# Sheet3                                                 None
# aphid sweep vs head count                              None
# head counts vs sweeps graphs                           None
#
#                                                         143
# Head Counts                                            None
# Sheet2                                                 None
# Sweep Samples Cereals           Hymenoptera_Proctotrupoidea
# Head Counts Edited                                     None
# Sweep Samples Cereals Edited                           None
# Data Sheets Combined                                   None
# Pivot chart LH phen                                    None
# leafhoppers 2016 cereal sweeps                         None
# Sheet3                                                 None
# aphid sweep vs head count                              None
# head counts vs sweeps graphs                           None
#
# [11 rows x 144 columns]

# %% [markdown]
# ### Initial Grouping

# %% [markdown]
# Based on sheet names and similarities between columns sets, I can probably group the sheets like so:
#
# - Head counts:
#   - Head Counts
#   - Head Counts Edited
# - Sweep:
#   - Sheet2
#   - Sweep Samples Cereals
#   - Sweep Samples Cereals Edited
#   - leafhoppers 2016 cereal sweeps
# - United:
#   - Data Sheets Combined
# - Analytical experiments:
#   - Pivot chart LH phen
#   - Sheet3
#   - aphid sweep vs head count
#   - head counts vs sweeps graphs

# %% [markdown]
# ## Sweep Samples Cereals vs Sheet2

# %% [markdown]
# I'd like to confirm that the vaguely named **Sheet2** is what it seems to be: a slightly edited copy of **Sweep Samples Cereals**.

# %% [markdown]
# ### Columns

# %%
sheet_names = ['Sweep Samples Cereals', 'Sheet2']
compare_sheets = ssc, s2 = [sheets[sheet_name] for sheet_name in sheet_names]
pandas.DataFrame(data=[sheet.columns for sheet in compare_sheets], index=sheet_names).T
# Out:
#                     Sweep Samples Cereals  \
# 0                                      ID
# 1                                Province
# 2                         Collection_Date
# 3                          Sample_by_week
# 4                            Date_by_week
# 5                                    Date
# 6                             Julian_date
# 7                                    Site
# 8                              Field_name
# 9                                    Crop
# 10                            Distance(m)
# 11                      Number of Samples
# 12                           Total Sweeps
# 13                              Total EGA
# 14                          EGA/20 Sweeps
# 15                              EGA/Sweep
# 16   Sitobion_avenae_EGA_green (wingless)
# 17                Sitobion_avenae_EGA_red
# 18                              EGA alate
# 19                  Bird_Cherry_Oat_Aphid
# 20                         greenbug_aphid
# 21                             pea aphids
# 22                  Total_apterous_aphids
# 23                     Total_alate_aphids
# 24                   4th_Instar_Pre-alate
# 25                         3rd_Instar_EGA
# 26               3rd_Instar_EGA_Pre-alate
# 27                         2nd_Instar_EGA
# 28                         1st_Instar_EGA
# 29          aphid_mummies_Aphelinus_black
# ..                                    ...
# 114                           Caterpillar
# 115                            Legume_Bug
# 116                            Chinch_Bug
# 117                           Ambush_Bugs
# 118                         Ichneumonidae
# 119          Pumace_Flies (Drosophilidae)
# 120                        Scorpion_Flies
# 121                 seed bugs (lygaeidea)
# 122                     Seed_Corn_Beetles
# 123                              UFI_bugs
# 124                           Wasps_Other
# 125                         Eulophid_Wasp
# 126                              Oribatid
# 127                          Spider_Mites
# 128                           Springtails
# 129                              Mollusks
# 130                            Formicidae
# 131                                weevil
# 132                     lepidopteran_pupa
# 133                          Unnamed: 133
# 134            Hymenoptera_Proctotrupidae
# 135              Hymenoptera_Pteromalidae
# 136                    Hymenoptera_Apidae
# 137             Hymenoptera_Diplazontinae
# 138                 Hymenoptera_Figitidae
# 139               Hymenoptera_Aphelinidae
# 140              Hymenoptera_Perilampidae
# 141              Hymenoptera_Chalcidoidea
# 142           Hymenoptera_Ichneumondoidea
# 143           Hymenoptera_Proctotrupoidea
#
#                                    Sheet2
# 0                                      ID
# 1                                Province
# 2                         Collection_Date
# 3                          Sample_by_week
# 4                            Date_by_week
# 5                                    Date
# 6                             Julian_date
# 7                                    Site
# 8                              Field_name
# 9                                    Crop
# 10                            Distance(m)
# 11                      Number of Samples
# 12   Sitobion_avenae_EGA_green (wingless)
# 13                Sitobion_avenae_EGA_red
# 14                              EGA alate
# 15                  Bird_Cherry_Oat_Aphid
# 16                         greenbug_aphid
# 17                             pea aphids
# 18                  Total_apterous_aphids
# 19                     Total_alate_aphids
# 20                   4th_Instar_Pre-alate
# 21                         3rd_Instar_EGA
# 22               3rd_Instar_EGA_Pre-alate
# 23                         2nd_Instar_EGA
# 24                         1st_Instar_EGA
# 25          aphid_mummies_Aphelinus_black
# 26           aphid_mummies_Aphidius_brown
# 27                          aphid_mummies
# 28      female_Macrosteles_quadrilineatus
# 29        male_Macrosteles_quadrilineatus
# ..                                    ...
# 114                         Ichneumonidae
# 115          Pumace_Flies (Drosophilidae)
# 116                        Scorpion_Flies
# 117                 seed bugs (lygaeidea)
# 118                     Seed_Corn_Beetles
# 119                              UFI_bugs
# 120                           Wasps_Other
# 121                         Eulophid_Wasp
# 122                              Oribatid
# 123                          Spider_Mites
# 124                           Springtails
# 125                              Mollusks
# 126                            Formicidae
# 127                                weevil
# 128                     lepidopteran_pupa
# 129                          Unnamed: 129
# 130            Hymenoptera_Proctotrupidae
# 131              Hymenoptera_Pteromalidae
# 132                    Hymenoptera_Apidae
# 133             Hymenoptera_Diplazontinae
# 134                 Hymenoptera_Figitidae
# 135               Hymenoptera_Aphelinidae
# 136              Hymenoptera_Perilampidae
# 137              Hymenoptera_Chalcidoidea
# 138           Hymenoptera_Ichneumondoidea
# 139           Hymenoptera_Proctotrupoidea
# 140                                  None
# 141                                  None
# 142                                  None
# 143                                  None
#
# [144 rows x 2 columns]

# %% [markdown]
# That seems to confirm that **Sheet2** has the same columns as **Sweep Samples Cereals** except for four columns that were removed.

# %%
set.symmetric_difference(*(set(sheet.columns.tolist()) for sheet in compare_sheets))
# Out:
# {'EGA/20 Sweeps',
#  'EGA/Sweep',
#  'Total EGA',
#  'Total Sweeps',
#  'Unnamed: 129',
#  'Unnamed: 133'}

# %% [markdown]
# The unnamed columns are inconsequential to our analysis. In fact, I believe they're empty. The rest have aggregate values that I don't trust. **Sweep Samples Cereals** is probably useless for my purposes.

# %% [markdown]
# ### Regarding Spreadsheet Formulas

# %% [markdown]
# Side note about saving aggregated data in an Excel workbook: use spreadsheet formulas, and leave the formulas in place—replacing easily evaluable symbolic expressions with calculated values is often unnecessary, not to mention counterproductive if anyone else might need to check your work.

# %% [markdown]
# ### Rows

# %% [markdown]
# What about the rows? I'll check sizes:

# %%
pandas.DataFrame(data=[sheets[sheet_name].index.size for sheet_name in sheet_names], index=sheet_names)
# Out:
#                          0
# Sweep Samples Cereals   92
# Sheet2                 668

# %% [markdown]
# It's pretty clear there is a lot more data in **Sheet2**. I suspect that **Sheet2** has additional data added to it. I'll have to take a closer look at the values, especially dates.

# %% [markdown]
# ### Dates

# %% [markdown]
# Before I can easily examine dates in the worksheets, I should convert them to proper datetime values:

# %%
for sheet in compare_sheets:
    sheet['Collection_Date'] = pandas.to_datetime(sheet['Collection_Date'], format='%d_%m_%Y')

# %% [markdown]
# Which sheet covers the earliest dates?

# %%
[sheet['Collection_Date'].min() for sheet in compare_sheets]
# Out:
# [Timestamp('2016-06-05 00:00:00'), Timestamp('2016-06-05 00:00:00')]

# %% [markdown]
# Neither.

# %% [markdown]
# Which sheet covers the latest dates?

# %%
[sheet['Collection_Date'].max() for sheet in compare_sheets]
# Out:
# [Timestamp('2017-07-08 00:00:00'), Timestamp('2017-07-08 00:00:00')]

# %% [markdown]
# Neither, again.

# %% [markdown]
# Are all the dates used in both?

# %%
[len(sheet['Collection_Date'].unique()) for sheet in compare_sheets]
# Out:
# [32, 34]

# %% [markdown]
# No, not exactly.

# %% [markdown]
# I need to check if all the dates in **Sweep Samples Cereals** are in **Sheet2**.

# %%
ssc.Collection_Date.isin(s2.Collection_Date).all()
# Out:
# True

# %% [markdown]
# **Sweep Samples Cereals** is most likely either a subset of **Sheet2**, or a reduced version of the same source data. **Sheet2** actually has more unique dates. Therefore, some dates in **Sheet2** must be absent from **Sweep Samples Cereals**.

# %%
s2.Collection_Date.isin(ssc.Collection_Date).all()
# Out:
# False

# %% [markdown]
# ### Dimensions

# %% [markdown]
# So, both sheets cover the same date range. **Sheet2** has two additional dates. I'm curious if one is aggregated from the other, especially since I see a "total sweeps" column in **Sweep Samples Cereals**.

# %%
ssc['Total Sweeps'].head()
# Out:
# 0    120
# 1    120
# 2     60
# 3    120
# 4     80
# Name: Total Sweeps, dtype: int64

# %% [markdown]
# I bet the sweeps were at different distances, and later reduced to sums. If I peek at the `Distance(m)` column, I should see a clear difference.

# %%
ssc['Distance(m)'].unique()
# Out:
# array(['Combined'], dtype=object)

# %%
s2['Distance(m)'].unique()
# Out:
# array([0, 5, 10, 25, 50, 100, 'Combined'], dtype=object)

# %% [markdown]
# Indeed, **Sheet2** has observations at various "distances", while **Sweep Samples Cereals** has only the invariate "Combined". Since I don't want reduced (aggregated) data, I don't want **Sweep Samples Cereals**.
#
# **Sheet2** has more rows because it isn't totalling up the sweeps from various distances. That makes **Sheet2** less reduced, and more "raw".

# %% [markdown]
# ### Conclusion – Optimal Candidate

# %% [markdown]
# Winner of the prize for completeness in data about sweep samples:
#
# - **Sheet2**
#
# I'll consider this my best source of truth for "sweep" data.

# %% [markdown]
# ## Sweep Samples Cereals Edited vs Sheet2

# %%
ssce = sheets['Sweep Samples Cereals Edited']
compare_sheets = ssce, s2

# %% [markdown]
# ### Columns

# %%
pandas.options.display.max_rows = 140
pandas.DataFrame(data=[sheet.columns for sheet in compare_sheets],
                 index=['Sweep Samples Cereals Edited', 'Sheet2']).T
# Out:
#                           Sweep Samples Cereals Edited  \
# 0                                                 Date
# 1                                                 Site
# 2                                                 Crop
# 3                                           Field_name
# 4                                          Sample Type
# 5                                         Total Sweeps
# 6                                           Unnamed: 6
# 7                                           Unnamed: 7
# 8                                            EGA_alate
# 9                                              EGA_apt
# 10                                           Total EGA
# 11                                       EGA/20 Sweeps
# 12                                           EGA/Sweep
# 13                                         Unnamed: 13
# 14                                         Unnamed: 14
# 15                                         Unnamed: 15
# 16                               Bird_Cherry_Oat_Aphid
# 17                                           BCO/Sweep
# 18                                         Unnamed: 18
# 19                        aphid_mummies_Aphidius_brown
# 20                                         Unnamed: 20
# 21                                       aphid_mummies
# 22                            other Coccinellid_adults
# 23                     Hippodamia_tredecimpunctata_C13
# 24                        Coccinella_septempunctata_C7
# 25                                    ladybugs- larvae
# 26                                     ladybugs_adults
# 27                                      ladybugs_total
# 28                                  Chrysopidae_adults
# 29                            Chrysoperla_carnea_adult
# 30                              Chrysopa_oculata_adult
# 31                            Chrysoperla_carnea_larva
# 32                             Chrysopa_oculata_larvae
# 33                                   G_lacewing_larvae
# 34                                     lacewing_larvae
# 35                                      lacewing_adult
# 36                                   Orius_tristicolor
# 37                                        Anthocoridae
# 38               ( Damsel bug)Nabis_americoferus_adult
# 39                            Nabis_americoferus_nymph
# 40                                            Nabicula
# 41                                    Nabis_alternatus
# 42                                       Chalcid_wasps
# 43                                   Aphelinus_varipes
# 44                                   Aphelinus_asychis
# 45                                 Aphelinus_albipodus
# 46                                      Braconid_wasps
# 47                                       Aphidiius_sp.
# 48                               any parasitoid_adults
# 49                                hyperparasitoids ???
# 50                                    Aphidencyrtus_sp
# 51                                   Asaphes_suspensus
# 52                                               flies
# 53                                         Lauxaniidae
# 54                                      Dolichopodidae
# 55                                       Syrphid_flies
# 56                                          Hoverflies
# 57                                   female_Delia_sp_1
# 58                                     male_Delia_sp_1
# 59                                   female_Delia_sp_2
# 60                                     male_Delia_sp_2
# 61                                  Anthomyiidae-Delia
# 62                                               midge
# 63                                     lygus_punctatus
# 64                                        Lygus_elisus
# 65                            Miridae_Lygus lineolaris
# 66                                         Lygus_nymph
# 67   Green_grass_bugs_Trigonotylus_coelestialium Mi...
# 68                                  Green_grass nymphs
# 69                                     Capsus_simulans
# 70                                            Katydids
# 71                                              Thrips
# 72                                        grasshoppers
# 73                                             spiders
# 74                               spider_Tetragnathidae
# 75                                          mosquitoes
# 76                              dragonflies+damsel fly
# 77                                    flea_beetles hop
# 78                                flea_beetles striped
# 79                               flea_beetles Crucifer
# 80                                           Cicindela
# 81                        Tychius_picirostris (weevil)
# 82                                    Bertha_Armyworms
# 83                                         Shield_Bugs
# 84                                               Worms
# 85                                             Beetles
# 86                                             Maggots
# 87                        Stink_Bugs (adult and nymph)
# 88                                            Red_Mite
# 89                                               Moths
# 90                                          Plant_Bugs
# 91                                        Pirate_Bugs
# 92                        Assassin_bug (Reduviid bugs)
# 93                                                Bees
# 94                                          Harvestman
# 95                                         Treehoppers
# 96                                   Cabbage_Butterfly
# 97                                         Caterpillar
# 98                                          Legume_Bug
# 99                                          Chinch_Bug
# 100                                        Ambush_Bugs
# 101                                      Ichneumonidae
# 102                       Pumace_Flies (Drosophilidae)
# 103                                     Scorpion_Flies
# 104                              seed bugs (lygaeidea)
# 105                                  Seed_Corn_Beetles
# 106                                           UFI_bugs
# 107                                        Wasps_Other
# 108                                      Eulophid_Wasp
# 109                                           Oribatid
# 110                                       Spider_Mites
# 111                                        Springtails
# 112                                           Mollusks
# 113                                         Formicidae
# 114                                             weevil
# 115                                  lepidopteran_pupa
# 116                                       Unnamed: 116
# 117                         Hymenoptera_Proctotrupidae
# 118                           Hymenoptera_Pteromalidae
# 119                                 Hymenoptera_Apidae
# 120                          Hymenoptera_Diplazontinae
# 121                              Hymenoptera_Figitidae
# 122                            Hymenoptera_Aphelinidae
# 123                           Hymenoptera_Perilampidae
# 124                           Hymenoptera_Chalcidoidea
# 125                        Hymenoptera_Ichneumondoidea
# 126                        Hymenoptera_Proctotrupoidea
# 127                                               None
# 128                                               None
# 129                                               None
# 130                                               None
# 131                                               None
# 132                                               None
# 133                                               None
# 134                                               None
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
#
#                                                 Sheet2
# 0                                                   ID
# 1                                             Province
# 2                                      Collection_Date
# 3                                       Sample_by_week
# 4                                         Date_by_week
# 5                                                 Date
# 6                                          Julian_date
# 7                                                 Site
# 8                                           Field_name
# 9                                                 Crop
# 10                                         Distance(m)
# 11                                   Number of Samples
# 12                Sitobion_avenae_EGA_green (wingless)
# 13                             Sitobion_avenae_EGA_red
# 14                                           EGA alate
# 15                               Bird_Cherry_Oat_Aphid
# 16                                      greenbug_aphid
# 17                                          pea aphids
# 18                               Total_apterous_aphids
# 19                                  Total_alate_aphids
# 20                                4th_Instar_Pre-alate
# 21                                      3rd_Instar_EGA
# 22                            3rd_Instar_EGA_Pre-alate
# 23                                      2nd_Instar_EGA
# 24                                      1st_Instar_EGA
# 25                       aphid_mummies_Aphelinus_black
# 26                        aphid_mummies_Aphidius_brown
# 27                                       aphid_mummies
# 28                   female_Macrosteles_quadrilineatus
# 29                     male_Macrosteles_quadrilineatus
# 30                   Macrosteles_quadrilineatus nymphs
# 31                              1st_Instar_Macrosteles
# 32                             2nd_Instar_Macrosteles
# 33                              3rd_Instar_Macrosteles
# 34                              4th_Instar_Macrosteles
# 35                               Athysanus_argentarius
# 36                                        Doratura_sp.
# 37                             Errastunus_ocellaris_LH
# 38                                   Other_leafhoppers
# 39                            other Coccinellid_adults
# 40                     Hippodamia_tredecimpunctata_C13
# 41                        Coccinella_septempunctata_C7
# 42                                    ladybugs- larvae
# 43                                  Chrysopidae_adults
# 44                            Chrysoperla_carnea_adult
# 45                              Chrysopa_oculata_adult
# 46                            Chrysoperla_carnea_larva
# 47                             Chrysopa_oculata_larvae
# 48                                   G_lacewing_larvae
# 49                                   Orius_tristicolor
# 50                                        Anthocoridae
# 51               ( Damsel bug)Nabis_americoferus_adult
# 52                            Nabis_americoferus_nymph
# 53                                            Nabicula
# 54                                    Nabis_alternatus
# 55                                       Chalcid_wasps
# 56                                   Aphelinus_varipes
# 57                                   Aphelinus_asychis
# 58                                 Aphelinus_albipodus
# 59                                      Braconid_wasps
# 60                                       Aphidiius_sp.
# 61                               any parasitoid_adults
# 62                                hyperparasitoids ???
# 63                                    Aphidencyrtus_sp
# 64                                   Asaphes_suspensus
# 65                                               flies
# 66                                         Lauxaniidae
# 67                                      Dolichopodidae
# 68                                       Syrphid_flies
# 69                                          Hoverflies
# 70                                   female_Delia_sp_1
# 71                                     male_Delia_sp_1
# 72                                   female_Delia_sp_2
# 73                                     male_Delia_sp_2
# 74                                  Anthomyiidae-Delia
# 75                                               midge
# 76                                     lygus_punctatus
# 77                                        Lygus_elisus
# 78                            Miridae_Lygus lineolaris
# 79                                         Lygus_nymph
# 80   Green_grass_bugs_Trigonotylus_coelestialium Mi...
# 81                                  Green_grass nymphs
# 82                                     Capsus_simulans
# 83                                            Katydids
# 84                                              Thrips
# 85                                        grasshoppers
# 86                                             spiders
# 87                               spider_Tetragnathidae
# 88                                          mosquitoes
# 89                              dragonflies+damsel fly
# 90                                    flea_beetles hop
# 91                                flea_beetles striped
# 92                               flea_beetles Crucifer
# 93                                           Cicindela
# 94                        Tychius_picirostris (weevil)
# 95                                    Bertha_Armyworms
# 96                                         Shield_Bugs
# 97                                               Worms
# 98                                             Beetles
# 99                                             Maggots
# 100                       Stink_Bugs (adult and nymph)
# 101                                           Red_Mite
# 102                                              Moths
# 103                                         Plant_Bugs
# 104                                       Pirate_Bugs
# 105                       Assassin_bug (Reduviid bugs)
# 106                                               Bees
# 107                                         Harvestman
# 108                                        Treehoppers
# 109                                  Cabbage_Butterfly
# 110                                        Caterpillar
# 111                                         Legume_Bug
# 112                                         Chinch_Bug
# 113                                        Ambush_Bugs
# 114                                      Ichneumonidae
# 115                       Pumace_Flies (Drosophilidae)
# 116                                     Scorpion_Flies
# 117                              seed bugs (lygaeidea)
# 118                                  Seed_Corn_Beetles
# 119                                           UFI_bugs
# 120                                        Wasps_Other
# 121                                      Eulophid_Wasp
# 122                                           Oribatid
# 123                                       Spider_Mites
# 124                                        Springtails
# 125                                           Mollusks
# 126                                         Formicidae
# 127                                             weevil
# 128                                  lepidopteran_pupa
# 129                                       Unnamed: 129
# 130                         Hymenoptera_Proctotrupidae
# 131                           Hymenoptera_Pteromalidae
# 132                                 Hymenoptera_Apidae
# 133                          Hymenoptera_Diplazontinae
# 134                              Hymenoptera_Figitidae
# 135                            Hymenoptera_Aphelinidae
# 136                           Hymenoptera_Perilampidae
# 137                           Hymenoptera_Chalcidoidea
# 138                        Hymenoptera_Ichneumondoidea
# 139                        Hymenoptera_Proctotrupoidea

# %% [markdown]
# **Sweep Samples Cereals Edited** seems to have left out some columns that would be expected to carry finely categorized subjects, such as various instars of aphids and leafhoppers. This makes it less likely to have information I'll need.
#
# Furthermore, it appears that **Sweep Samples Cereals Edited** has a column that is probably an artefact from aggregation: `Total Sweeps`. It's also missing the `Distance(m)` column; another sign of aggregation, and therefore loss of some information.
#
# I hope I can ignore the whole worksheet, just as I'll be doing with **Sweep Samples Cereals** ("unedited"). Unless further analysis reveals that **Sweep Samples Cereals Edited** has dates that are missing from **Sheet2**, I'll assume it's not worth closer examination.

# %% [markdown]
# ### Rows

# %%
print(f'{ssce.index.size / s2.index.size:.0%}')
# Out:
# 14%

# %% [markdown]
# **Sweep Samples Cereals Edited** has 14% the number of rows as **Sheet2**, so it's not likely to be useful, unless the dates don't fully overlap.

# %% [markdown]
# ### Dates

# %%
def index_size(pandas_object):
    return len(pandas_object.unique())


descriptors = [pandas.Series.max, pandas.Series.min, index_size]
ssce.Date.apply(descriptors)
# Out:
# max           2016-08-15 00:00:00
# min           2016-06-05 00:00:00
# index_size                     31
# Name: Date, dtype: object

# %%
s2.Collection_Date.apply(descriptors)
# Out:
# max           2017-07-08 00:00:00
# min           2016-06-05 00:00:00
# index_size                     34
# Name: Collection_Date, dtype: object

# %% [markdown]
# It appears that **Sweep Samples Cereals Edited**, like **Sweep Samples Cereals**, has a much shorter date range, so we won't be missing anything if we ignore it. To be sure, I need to check if all the dates in **Sweep Samples Cereals Edited** are in **Sheet2**.

# %%
ssce.Date.isin(s2.Collection_Date).all()
# Out:
# True

# %% [markdown]
# Excellent. I see no reason to pay attention to **Sweep Samples Cereals Edited** or **Sweep Samples Cereals** anymore. Perhaps if I have time after fixing the graph, I will trace the cause of the error, and it may lead me back to one of those worksheets.

# %% [markdown]
# ### Conclusion – Optimal Candidate

# %% [markdown]
# Winner of the prize for completeness in data about sweep samples:
#
# - **Sheet2** (again)
#
# I'll consider this my best source of truth for "sweep" data.

# %% [markdown]
# ## leafhoppers 2016 cereal sweeps vs Sheet2

# %%
sheet_names = ['leafhoppers 2016 cereal sweeps', 'Sheet2']
lh2016, s2 = compare_sheets = [sheets[sheet_name] for sheet_name in sheet_names]

# %% [markdown]
# ### Columns

# %%
columns = [frame.columns for frame in compare_sheets]
pandas.DataFrame(data=columns, index=sheet_names).T.head(lh2016.columns.size)
# Out:
#        leafhoppers 2016 cereal sweeps                                Sheet2
# 0                     Collection_Date                                    ID
# 1                      Sample_by_week                              Province
# 2                        Date_by_week                       Collection_Date
# 3                                Date                        Sample_by_week
# 4                         Julian_date                          Date_by_week
# 5                                Site                                  Date
# 6                          Field_name                           Julian_date
# 7                                Crop                                  Site
# 8                         Distance(m)                            Field_name
# 9                   Number of Samples                                  Crop
# 10                       Total Sweeps                           Distance(m)
# 11  female_Macrosteles_quadrilineatus                     Number of Samples
# 12    male_Macrosteles_quadrilineatus  Sitobion_avenae_EGA_green (wingless)
# 13  Macrosteles_quadrilineatus nymphs               Sitobion_avenae_EGA_red
# 14             1st_Instar_Macrosteles                             EGA alate
# 15            2nd_Instar_Macrosteles                  Bird_Cherry_Oat_Aphid
# 16             3rd_Instar_Macrosteles                        greenbug_aphid
# 17             4th_Instar_Macrosteles                            pea aphids
# 18              Athysanus_argentarius                 Total_apterous_aphids
# 19                       Doratura_sp.                    Total_alate_aphids
# 20            Errastunus_ocellaris_LH                  4th_Instar_Pre-alate
# 21                  Other_leafhoppers                        3rd_Instar_EGA

# %% [markdown]
# Clearly, **leafhoppers 2016 cereal sweeps** is focused on leafhoppers.

# %%
lh2016['Total Sweeps'].unique()
# Out:
# array([120,  60,  80,  20, 100,  40])

# %%
lh2016['Distance(m)'].unique()
# Out:
# array(['Combined'], dtype=object)

# %%
lh2016['Number of Samples'].unique()
# Out:
# array([6, 3, 4, 1, 5, 2])

# %% [markdown]
# #### Rows

# %%
pandas.DataFrame(data={sheet_name: sheet.index.size for sheet_name, sheet in zip(sheet_names, compare_sheets)}, index=['number of rows']).rename_axis(['worksheet'], axis='columns').T.sort_values(by='number of rows')
# Out:
#                                 number of rows
# worksheet
# leafhoppers 2016 cereal sweeps              92
# Sheet2                                     668
